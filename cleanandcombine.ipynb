# %%
# Dependencies and Setup
import pandas as pd

# Files to Load 
Sept2018 = "CSV/JC-201809-citibike-tripdata.csv"
Oct2018 = "CSV/JC-201810-citibike-tripdata.csv"
Nov2018 = "CSV/JC-201811-citibike-tripdata.csv"

# Read from CSV
Sept2018_df = pd.read_csv(Sept2018)
Oct2018_df = pd.read_csv(Oct2018)
Nov2018_df = pd.read_csv(Nov2018)

Oct2018_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               152  2018-10-01 07:44:41.4170  2018-10-01 07:47:14.2960
# 1               122  2018-10-01 08:50:05.4340  2018-10-01 08:52:08.2250
# 2               211  2018-10-01 09:03:17.0640  2018-10-01 09:06:48.0940
# 3               342  2018-10-01 10:13:07.0090  2018-10-01 10:18:49.8960
# 4              2976  2018-10-01 10:45:14.2800  2018-10-01 11:34:51.2610
# ...             ...                       ...                       ...
# 39133          1118  2018-10-31 11:30:53.7070  2018-10-31 11:49:32.4850
# 39134          1242  2018-10-31 12:20:41.6990  2018-10-31 12:41:24.4270
# 39135          1188  2018-10-31 12:21:36.2790  2018-10-31 12:41:24.3540
# 39136           983  2018-10-31 14:27:59.9590  2018-10-31 14:44:23.2020
# 39137           544  2018-10-31 15:37:41.3760  2018-10-31 15:46:45.5090
#
#        start station id start station name  start station latitude  \
# ...

# %%
Sept_Nov2018_df = Sept2018_df
Sept_Nov2018_df = Sept_Nov2018_df.append(Oct2018_df, ignore_index=True)
Sept_Nov2018_df = Sept_Nov2018_df.append(Nov2018_df, ignore_index=True)

#Sept_Nov2018_df.to_csv("CSV/cleaned/2018.csv")
Sept_Nov2018_df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                284  2018-09-01 01:48:22.0320  2018-09-01 01:53:06.9130
# 1                370  2018-09-01 01:48:22.5010  2018-09-01 01:54:32.9270
# 2               1181  2018-09-01 09:37:04.3070  2018-09-01 09:56:45.3280
# 3                383  2018-09-01 09:44:46.0030  2018-09-01 09:51:09.9230
# 4                377  2018-09-01 09:44:46.1850  2018-09-01 09:51:03.6330
# ...              ...                       ...                       ...
# 103065           734  2018-11-28 10:46:12.6640  2018-11-28 10:58:27.0750
# 103066           312  2018-11-28 19:52:40.1140  2018-11-28 19:57:52.9270
# 103067           914  2018-11-29 10:20:57.7240  2018-11-29 10:36:12.0420
# 103068          2392  2018-11-29 17:28:24.1590  2018-11-29 18:08:16.8720
# 103069           637  2018-11-30 12:00:10.4100  2018-11-30 12:10:48.0210
#
#         start station id start station name  start station latitude  \
# ...

# %%
# Files to Load 
Sept2019 = "CSV/JC-201909-citibike-tripdata.csv"
Oct2019 = "CSV/JC-201910-citibike-tripdata.csv"
Nov2019 = "CSV/JC-201911-citibike-tripdata.csv"

# Read from CSV
Sept2019_df = pd.read_csv(Sept2019)
Oct2019_df = pd.read_csv(Oct2019)
Nov2019_df = pd.read_csv(Nov2019)

Oct2019_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               892  2019-10-01 00:20:05.0140  2019-10-01 00:34:57.3800
# 1               374  2019-10-01 00:43:48.8790  2019-10-01 00:50:03.8190
# 2               170  2019-10-01 01:35:51.8630  2019-10-01 01:38:42.5470
# 3               946  2019-10-01 02:55:53.4000  2019-10-01 03:11:40.2710
# 4               517  2019-10-01 03:10:16.1290  2019-10-01 03:18:53.6350
# ...             ...                       ...                       ...
# 42248           287  2019-10-31 23:42:25.1120  2019-10-31 23:47:12.6180
# 42249           532  2019-10-31 23:48:07.5720  2019-10-31 23:56:59.7280
# 42250           202  2019-10-31 23:50:04.3480  2019-10-31 23:53:26.6230
# 42251           841  2019-10-31 23:53:24.5280  2019-11-01 00:07:25.8950
# 42252           268  2019-10-31 23:53:45.6170  2019-10-31 23:58:13.8980
#
#        start station id start station name  start station latitude  \
# ...

# %%
Sept_Nov2019_df = Sept2019_df
Sept_Nov2019_df = Sept_Nov2019_df.append(Oct2019_df, ignore_index=True)
Sept_Nov2019_df = Sept_Nov2019_df.append(Nov2019_df, ignore_index=True)

Sept_Nov2019_df.to_csv("CSV/cleaned/2019.csv")
Sept_Nov2019_df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                145  2019-09-01 00:00:37.6920  2019-09-01 00:03:03.0100
# 1                212  2019-09-01 00:03:00.6000  2019-09-01 00:06:33.3420
# 2                569  2019-09-01 00:07:13.0020  2019-09-01 00:16:42.8610
# 3               1380  2019-09-01 00:07:25.3350  2019-09-01 00:30:26.1640
# 4               1346  2019-09-01 00:07:56.4670  2019-09-01 00:30:22.5440
# ...              ...                       ...                       ...
# 122289            77  2019-11-30 23:30:07.7850  2019-11-30 23:31:25.7730
# 122290           145  2019-11-30 23:40:45.3790  2019-11-30 23:43:10.5660
# 122291            99  2019-11-30 23:41:55.3310  2019-11-30 23:43:34.3320
# 122292           594  2019-11-30 23:52:50.2410  2019-12-01 00:02:44.2960
# 122293           329  2019-11-30 23:56:27.6680  2019-12-01 00:01:57.0120
#
#         start station id          start station name  start station latitude  \
# ...

# %%
all_df = Sept_Nov2018_df.append(Sept_Nov2019_df, ignore_index=True)
all_df.to_csv("CSV/cleaned/all.csv")
all_df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                284  2018-09-01 01:48:22.0320  2018-09-01 01:53:06.9130
# 1                370  2018-09-01 01:48:22.5010  2018-09-01 01:54:32.9270
# 2               1181  2018-09-01 09:37:04.3070  2018-09-01 09:56:45.3280
# 3                383  2018-09-01 09:44:46.0030  2018-09-01 09:51:09.9230
# 4                377  2018-09-01 09:44:46.1850  2018-09-01 09:51:03.6330
# ...              ...                       ...                       ...
# 225359            77  2019-11-30 23:30:07.7850  2019-11-30 23:31:25.7730
# 225360           145  2019-11-30 23:40:45.3790  2019-11-30 23:43:10.5660
# 225361            99  2019-11-30 23:41:55.3310  2019-11-30 23:43:34.3320
# 225362           594  2019-11-30 23:52:50.2410  2019-12-01 00:02:44.2960
# 225363           329  2019-11-30 23:56:27.6680  2019-12-01 00:01:57.0120
#
#         start station id          start station name  start station latitude  \
# ...
